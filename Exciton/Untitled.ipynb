# %%
import pandas as pd
import json

# %%
with open("exciton_data.json") as d:
    data = json.load(d)

df = pd.DataFrame.from_dict(data)

# %%
df
# Out:
#        monomer A  monomer B ring A ring B  frame   distance  \
# 0              1          2  B850a   B800      1  46.870688
# 1              1          3  B850a  B850b      1  18.775979
# 2              1          4  B850a  B850a      1  33.518741
# 3              1          5  B850a   B800      1  77.018233
# 4              1          6  B850a  B850b      1  51.196162
# ...          ...        ...    ...    ...    ...        ...
# 70195         24         26  B850b   B800  49751  63.743820
# 70196         24         27  B850b  B850b  49751  35.066438
# 70197         25         26  B850a   B800  49751  48.518499
# 70198         25         27  B850a  B850b  49751  18.137968
# 70199         26         27   B800  B850b  49751  37.346230
#
#        charge centre distance    coupling  \
# 0                   44.068932  -17.104468
# 1                   17.135812 -359.656912
# 2                   33.369960   73.699876
# 3                   74.607113    5.103755
# ...
